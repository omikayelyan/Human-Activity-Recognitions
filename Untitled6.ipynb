# %%
import pandas as pd

# Read CSV file
train_data = pd.read_csv("train.csv")

test_data = pd.read_csv("test.csv")

print(train_data.shape)
train_data.dropna(inplace=True)
print(train_data.shape)

X_train = train_data.iloc[:,:-1]
y_train = train_data.iloc[:,-1]

X_test = test_data.iloc[:,:-1]
y_test = test_data.iloc[:,-1]
# Out:
# (3041, 563)
# (3040, 563)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

model =   SVC(
    kernel='poly',
    C=1.0,
    degree=3,
    gamma='scale',
    coef0=0.0
)
# Train (fit) the model
model.fit(X_train, y_train)

# Predict on test data
y_pred = model.predict(X_test)

# Evaluate
print("Accuracy Test:", accuracy_score(y_test, y_pred))
print("Accuracy Train:",accuracy_score(y_train, model.predict(X_train)))
# Out:
# Accuracy Test: 0.8995588734306074
# Accuracy Train: 0.9907894736842106

# %%
model = SVC(kernel='linear')
# Train (fit) the model
model.fit(X_train, y_train)

# Predict on test data
y_pred = model.predict(X_test)

# Evaluate
print("Accuracy Test:", accuracy_score(y_test, y_pred))
print("Accuracy Train:",accuracy_score(y_train, model.predict(X_train)))
# Out:
# Accuracy Test: 0.8914149983033594
# Accuracy Train: 0.9980263157894737

# %%
from sklearn.tree import DecisionTreeClassifier

# Create model
model = DecisionTreeClassifier(max_depth=3)

# Train
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Accuracy Train:",accuracy_score(y_train, model.predict(X_train)))
# Out:
# Accuracy: 0.7156430268069223
# Accuracy Train: 0.7917763157894737

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create model
model = KNeighborsClassifier(n_neighbors=5)

# Train
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Accuracy Train:",accuracy_score(y_train, model.predict(X_train)))
# Out:
# Accuracy: 0.7835086528673227
# Accuracy Train: 0.9888157894736842

# %%
from sklearn.ensemble import AdaBoostClassifier


# Create AdaBoost model
model = AdaBoostClassifier(
    n_estimators = 100,
    learning_rate= 0.5,
    random_state=42
)

# Train
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Accuracy Train:",accuracy_score(y_train, model.predict(X_train)))
# Out:
# Accuracy: 0.3505259586019681
# Accuracy Train: 0.36546052631578946

# %%
from sklearn.ensemble import GradientBoostingClassifier


# Create model
model = GradientBoostingClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42
)

# Train
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluate
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Accuracy Train:",accuracy_score(y_train, model.predict(X_train)))
# Out:
# Accuracy: 0.8469630132337971
# Accuracy Train: 1.0
