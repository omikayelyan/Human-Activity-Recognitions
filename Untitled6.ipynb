# %%
import pandas as pd

# Read CSV file
train_data = pd.read_csv("train.csv")

test_data = pd.read_csv("test.csv")

print(train_data.shape)
train_data.dropna(inplace=True)
print(train_data.shape)

X_train = train_data.iloc[:,:-1]
y_train = train_data.iloc[:,-1]

X_test = test_data.iloc[:,:-1]
y_test = test_data.iloc[:,-1]


train_data.columns
# Out:
# (7352, 563)
# (7352, 563)
# Index(['tBodyAcc-mean()-X', 'tBodyAcc-mean()-Y', 'tBodyAcc-mean()-Z',
#        'tBodyAcc-std()-X', 'tBodyAcc-std()-Y', 'tBodyAcc-std()-Z',
#        'tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z',
#        'tBodyAcc-max()-X',
#        ...
#        'fBodyBodyGyroJerkMag-kurtosis()', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyAccJerkMean),gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)',
#        'angle(tBodyGyroJerkMean,gravityMean)', 'angle(X,gravityMean)',
#        'angle(Y,gravityMean)', 'angle(Z,gravityMean)', 'subject', 'Activity'],
#       dtype='object', length=563)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

model =   SVC(
    kernel='poly',
    C=1.0,
    degree=3,
    gamma='scale',
    coef0=0.0
)
# Train (fit) the model
model.fit(X_train, y_train)

# Predict on test data
y_pred = model.predict(X_test)

# Evaluate
print("Accuracy Test:", accuracy_score(y_test, y_pred))
print("Accuracy Train:",accuracy_score(y_train, model.predict(X_train)))
# Out:
# Accuracy Test: 0.9178825924669155
# Accuracy Train: 0.9604189336235038

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

model =   SVC(
    kernel='rbf',
    C=1.0,
    degree=3,
    gamma='scale',
    coef0=0.0
)
# Train (fit) the model
model.fit(X_train, y_train)

# Predict on test data
y_pred = model.predict(X_test)

# Evaluate
print("Accuracy Test:", accuracy_score(y_test, y_pred))
print("Accuracy Train:",accuracy_score(y_train, model.predict(X_train)))
# Out:
# Accuracy Test: 0.9307770614183916
# Accuracy Train: 0.9581066376496191

# %%
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score
)

model = SVC(kernel='linear')

# Train (fit) the model
model.fit(X_train, y_train)

# Predict on test data
y_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)

# Accuracy
print("Accuracy Test:", accuracy_score(y_test, y_pred))
print("Accuracy Train:", accuracy_score(y_train, y_train_pred))

# Confusion Matrix
print("\nConfusion Matrix (Test):")
print(confusion_matrix(y_test, y_pred))

# Precision, Recall, F1
print("\nPrecision (macro):", precision_score(y_test, y_pred, average='macro'))
print("Recall (macro):", recall_score(y_test, y_pred, average='macro'))
print("F1-score (macro):", f1_score(y_test, y_pred, average='macro'))

# Full Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Test: 0.9633525619273838
# Accuracy Train: 0.9940152339499456
#
# Confusion Matrix (Test):
# [[537   0   0   0   0   0]
#  [  0 435  55   0   0   1]
#  [  0  16 516   0   0   0]
#  [  0   0   0 494   1   1]
#  [  0   0   0   4 410   6]
#  [  0   0   0  22   2 447]]
#
# Precision (macro): 0.965559116635769
# Recall (macro): 0.9628457771644122
# F1-score (macro): 0.9635790742787718
#
# Classification Report:
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.96      0.89      0.92       491
#           STANDING       0.90      0.97      0.94       532
#            WALKING       0.95      1.00      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.98      0.98       420
#   WALKING_UPSTAIRS       0.98      0.95      0.97       471
#
#           accuracy                           0.96      2947
#          macro avg       0.97      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %%
from sklearn.linear_model import LogisticRegression

# Create model
model = LogisticRegression(max_iter=1000)

# Train
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

#Eval
print("Accuracy Test:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Test: 0.9599592806243638

# %%
# from sklearn.tree import DecisionTreeClassifier

# # Create model
# model = DecisionTreeClassifier(max_depth=3)

# # Train
# model.fit(X_train, y_train)

# # Predict
# y_pred = model.predict(X_test)

# # Evaluate
# print("Accuracy:", accuracy_score(y_test, y_pred))
# print("Accuracy Train:",accuracy_score(y_train, model.predict(X_train)))
# Out:
# Accuracy: 0.7224295894129623
# Accuracy Train: 0.7879488574537541

# %%
# from sklearn.neighbors import KNeighborsClassifier

# # Create model
# model = KNeighborsClassifier(n_neighbors=5)

# # Train
# model.fit(X_train, y_train)

# # Predict
# y_pred = model.predict(X_test)

# # Accuracy
# print("Accuracy:", accuracy_score(y_test, y_pred))
# print("Accuracy Train:",accuracy_score(y_train, model.predict(X_train)))
# Out:
# Accuracy: 0.8096369189005769
# Accuracy Train: 0.9889825897714908

# %%
# from sklearn.ensemble import AdaBoostClassifier


# # Create AdaBoost model
# model = AdaBoostClassifier(
#     n_estimators = 100,
#     learning_rate= 0.5,
#     random_state=42
# )

# # Train
# model.fit(X_train, y_train)

# # Predict
# y_pred = model.predict(X_test)

# # Evaluate
# print("Accuracy:", accuracy_score(y_test, y_pred))
# print("Accuracy Train:",accuracy_score(y_train, model.predict(X_train)))
# Out:
# Accuracy: 0.505259586019681
# Accuracy Train: 0.5121055495103374

# %%
# from sklearn.ensemble import GradientBoostingClassifier


# # Create model
# model = GradientBoostingClassifier(
#     n_estimators=100,
#     learning_rate=0.1,
#     max_depth=3,
#     random_state=42
# )

# # Train
# model.fit(X_train, y_train)

# # Predict
# y_pred = model.predict(X_test)

# # Evaluate
# print("Accuracy:", accuracy_score(y_test, y_pred))
# print("Accuracy Train:",accuracy_score(y_train, model.predict(X_train)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3985002786.py in <cell line: 0>()
#      11
#      12 # Train
# ---> 13 model.fit(X_train, y_train)
#      14
#      15 # Predict
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/ensemble/_gb.py in fit(self, X, y, sample_weight, monitor)
#     785
#     786         # fit the boosting stages
# --> 787         n_stages = self._fit_stages(
#     788             X_train,
#     789             y_train,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/ensemble/_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     881
#     882             # fit next stage of trees
# --> 883             raw_predictions = self._fit_stage(
#     884                 i,
#     885                 X,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/ensemble/_gb.py in _fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     487
#     488             X = X_csc if X_csc is not None else X
# --> 489             tree.fit(
#     490                 X, neg_g_view[:, k], sample_weight=sample_weight, check_input=False
#     491             )
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#    1402         """
#    1403
# -> 1404         super()._fit(
#    1405             X,
#    1406             y,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/tree/_classes.py in _fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     470             )
#     471
# --> 472         builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     473
#     474         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
best_150_features = [
    # tBodyAcc
    "tBodyAcc-mean()-X", "tBodyAcc-mean()-Y", "tBodyAcc-mean()-Z",
    "tBodyAcc-std()-X", "tBodyAcc-std()-Y", "tBodyAcc-std()-Z",
    "tBodyAcc-mad()-X", "tBodyAcc-mad()-Y", "tBodyAcc-mad()-Z",
    "tBodyAcc-min()-X", "tBodyAcc-min()-Y", "tBodyAcc-min()-Z",
    "tBodyAcc-max()-X", "tBodyAcc-max()-Y", "tBodyAcc-max()-Z",
    "tBodyAcc-iqr()-X", "tBodyAcc-iqr()-Y", "tBodyAcc-iqr()-Z",
    "tBodyAcc-sma()", "tBodyAcc-energy()-X", "tBodyAcc-energy()-Y", "tBodyAcc-energy()-Z",
    "tBodyAcc-skewness()-X", "tBodyAcc-skewness()-Y", "tBodyAcc-skewness()-Z",
    "tBodyAcc-kurtosis()-X", "tBodyAcc-kurtosis()-Y", "tBodyAcc-kurtosis()-Z",
    "tBodyAcc-arCoeff()-X,1", "tBodyAcc-arCoeff()-X,2", "tBodyAcc-arCoeff()-X,3", "tBodyAcc-arCoeff()-X,4",
    "tBodyAcc-arCoeff()-Y,1", "tBodyAcc-arCoeff()-Y,2", "tBodyAcc-arCoeff()-Y,3", "tBodyAcc-arCoeff()-Y,4",
    "tBodyAcc-arCoeff()-Z,1", "tBodyAcc-arCoeff()-Z,2", "tBodyAcc-arCoeff()-Z,3", "tBodyAcc-arCoeff()-Z,4",
    "tBodyAcc-correlation()-X,Y", "tBodyAcc-correlation()-X,Z", "tBodyAcc-correlation()-Y,Z",

    # tBodyAccJerk
    "tBodyAccJerk-mean()-X", "tBodyAccJerk-mean()-Y", "tBodyAccJerk-mean()-Z",
    "tBodyAccJerk-std()-X", "tBodyAccJerk-std()-Y", "tBodyAccJerk-std()-Z",
    "tBodyAccJerk-mad()-X", "tBodyAccJerk-mad()-Y", "tBodyAccJerk-mad()-Z",
    "tBodyAccJerk-min()-X", "tBodyAccJerk-min()-Y", "tBodyAccJerk-min()-Z",
    "tBodyAccJerk-max()-X", "tBodyAccJerk-max()-Y", "tBodyAccJerk-max()-Z",
    "tBodyAccJerk-iqr()-X", "tBodyAccJerk-iqr()-Y", "tBodyAccJerk-iqr()-Z",
    "tBodyAccJerk-sma()", "tBodyAccJerk-energy()-X", "tBodyAccJerk-energy()-Y", "tBodyAccJerk-energy()-Z",
    "tBodyAccJerk-skewness()-X", "tBodyAccJerk-skewness()-Y", "tBodyAccJerk-skewness()-Z",
    "tBodyAccJerk-kurtosis()-X", "tBodyAccJerk-kurtosis()-Y", "tBodyAccJerk-kurtosis()-Z",
    "tBodyAccJerk-arCoeff()-X,1", "tBodyAccJerk-arCoeff()-X,2", "tBodyAccJerk-arCoeff()-X,3", "tBodyAccJerk-arCoeff()-X,4",
    "tBodyAccJerk-arCoeff()-Y,1", "tBodyAccJerk-arCoeff()-Y,2", "tBodyAccJerk-arCoeff()-Y,3", "tBodyAccJerk-arCoeff()-Y,4",
    "tBodyAccJerk-arCoeff()-Z,1", "tBodyAccJerk-arCoeff()-Z,2", "tBodyAccJerk-arCoeff()-Z,3", "tBodyAccJerk-arCoeff()-Z,4",
    "tBodyAccJerk-correlation()-X,Y", "tBodyAccJerk-correlation()-X,Z", "tBodyAccJerk-correlation()-Y,Z",

    # tBodyGyro
    "tBodyGyro-mean()-X", "tBodyGyro-mean()-Y", "tBodyGyro-mean()-Z",
    "tBodyGyro-std()-X", "tBodyGyro-std()-Y", "tBodyGyro-std()-Z",
    "tBodyGyro-mad()-X", "tBodyGyro-mad()-Y", "tBodyGyro-mad()-Z",
    "tBodyGyro-min()-X", "tBodyGyro-min()-Y", "tBodyGyro-min()-Z",
    "tBodyGyro-max()-X", "tBodyGyro-max()-Y", "tBodyGyro-max()-Z",
    "tBodyGyro-iqr()-X", "tBodyGyro-iqr()-Y", "tBodyGyro-iqr()-Z",
    "tBodyGyro-sma()", "tBodyGyro-energy()-X", "tBodyGyro-energy()-Y", "tBodyGyro-energy()-Z",
    "tBodyGyro-skewness()-X", "tBodyGyro-skewness()-Y", "tBodyGyro-skewness()-Z",
    "tBodyGyro-kurtosis()-X", "tBodyGyro-kurtosis()-Y", "tBodyGyro-kurtosis()-Z",
    "tBodyGyro-arCoeff()-X,1", "tBodyGyro-arCoeff()-X,2", "tBodyGyro-arCoeff()-X,3", "tBodyGyro-arCoeff()-X,4",
    "tBodyGyro-arCoeff()-Y,1", "tBodyGyro-arCoeff()-Y,2", "tBodyGyro-arCoeff()-Y,3", "tBodyGyro-arCoeff()-Y,4",
    "tBodyGyro-arCoeff()-Z,1", "tBodyGyro-arCoeff()-Z,2", "tBodyGyro-arCoeff()-Z,3", "tBodyGyro-arCoeff()-Z,4",
    "tBodyGyro-correlation()-X,Y", "tBodyGyro-correlation()-X,Z", "tBodyGyro-correlation()-Y,Z",

    # tBodyGyroJerk
    "tBodyGyroJerk-mean()-X", "tBodyGyroJerk-mean()-Y", "tBodyGyroJerk-mean()-Z",
    "tBodyGyroJerk-std()-X", "tBodyGyroJerk-std()-Y", "tBodyGyroJerk-std()-Z",
    "tBodyGyroJerk-mad()-X", "tBodyGyroJerk-mad()-Y", "tBodyGyroJerk-mad()-Z",
    "tBodyGyroJerk-min()-X", "tBodyGyroJerk-min()-Y", "tBodyGyroJerk-min()-Z",
    "tBodyGyroJerk-max()-X", "tBodyGyroJerk-max()-Y", "tBodyGyroJerk-max()-Z",
    "tBodyGyroJerk-iqr()-X", "tBodyGyroJerk-iqr()-Y", "tBodyGyroJerk-iqr()-Z",
    "tBodyGyroJerk-sma()", "tBodyGyroJerk-energy()-X", "tBodyGyroJerk-energy()-Y"
]

# Filter X_train
X_train_reduce = X_train[best_150_features]
X_test_reduce = X_test[best_150_features]

print("Original shape:", X_train_reduce.shape)
print("Original:",X_test_reduce.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2443877122.py in <cell line: 0>()
#      56
#      57 # Filter X_train
# ---> 58 X_train_reduce = X_train[best_150_features]
#      59 X_test_reduce = X_test[best_150_features]
#      60
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252             raise KeyError(f"{not_found} not in index")
#    6253
#    6254     @overload
#
# KeyError: "['tBodyAcc-mad()-X', 'tBodyAcc-mad()-Y', 'tBodyAcc-mad()-Z', 'tBodyAcc-min()-X', 'tBodyAcc-min()-Y', 'tBodyAcc-min()-Z', 'tBodyAcc-max()-X', 'tBodyAcc-max()-Y', 'tBodyAcc-max()-Z', 'tBodyAcc-iqr()-X', 'tBodyAcc-iqr()-Y', 'tBodyAcc-iqr()-Z', 'tBodyAcc-sma()', 'tBodyAcc-skewness()-X', 'tBodyAcc-skewness()-Y', 'tBodyAcc-skewness()-Z', 'tBodyAcc-kurtosis()-X', 'tBodyAcc-kurtosis()-Y', 'tBodyAcc-kurtosis()-Z', 'tBodyAcc-arCoeff()-X,1', 'tBodyAcc-arCoeff()-X,2', 'tBodyAcc-arCoeff()-X,3', 'tBodyAcc-arCoeff()-X,4', 'tBodyAcc-arCoeff()-Y,1', 'tBodyAcc-arCoeff()-Y,2', 'tBodyAcc-arCoeff()-Y,3', 'tBodyAcc-arCoeff()-Y,4', 'tBodyAcc-arCoeff()-Z,1', 'tBodyAcc-arCoeff()-Z,2', 'tBodyAcc-arCoeff()-Z,3', 'tBodyAcc-arCoeff()-Z,4', 'tBodyAcc-correlation()-X,Y', 'tBodyAcc-correlation()-X,Z', 'tBodyAcc-correlation()-Y,Z', 'tBodyAccJerk-mad()-X', 'tBodyAccJerk-mad()-Y', 'tBodyAccJerk-mad()-Z', 'tBodyAccJerk-min()-X', 'tBodyAccJerk-min()-Y', 'tBodyAccJerk-min()-Z', 'tBodyAccJerk-max()-X', 'tBodyAccJerk-max()-Y', 'tBodyAccJerk-max()-Z', 'tBodyAccJerk-iqr()-X', 'tBodyAccJerk-iqr()-Y', 'tBodyAccJerk-iqr()-Z', 'tBodyAccJerk-sma()', 'tBodyAccJerk-energy()-X', 'tBodyAccJerk-energy()-Y', 'tBodyAccJerk-energy()-Z', 'tBodyAccJerk-skewness()-X', 'tBodyAccJerk-skewness()-Y', 'tBodyAccJerk-skewness()-Z', 'tBodyAccJerk-kurtosis()-X', 'tBodyAccJerk-kurtosis()-Y', 'tBodyAccJerk-kurtosis()-Z', 'tBodyAccJerk-arCoeff()-X,1', 'tBodyAccJerk-arCoeff()-X,2', 'tBodyAccJerk-arCoeff()-X,3', 'tBodyAcc...

# %%
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    precision_score,
    recall_score,
    f1_score
)

model = SVC(kernel='linear')

# Train (fit) the model
model.fit(X_train_reduce, y_train)

# Predict on test data
y_pred = model.predict(X_test_reduce)
y_train_pred = model.predict(X_train)

# Accuracy
print("Accuracy Test:", accuracy_score(y_test, y_pred))
print("Accuracy Train:", accuracy_score(y_train, y_train_pred))

# Confusion Matrix
print("\nConfusion Matrix (Test):")
print(confusion_matrix(y_test, y_pred))

# Precision, Recall, F1
print("\nPrecision (macro):", precision_score(y_test, y_pred, average='macro'))
print("Recall (macro):", recall_score(y_test, y_pred, average='macro'))
print("F1-score (macro):", f1_score(y_test, y_pred, average='macro'))

# Full Classification Report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print(X_train.shape)
# Out:
# Accuracy Test: 0.7634882931795046
# Accuracy Train: 0.7282372143634385
#
# Confusion Matrix (Test):
# [[517   1  19   0   0   0]
#  [326 130  35   0   0   0]
#  [210  24 298   0   0   0]
#  [  0   0   0 487   5   4]
#  [  0   0   0   5 386  29]
#  [  0   0   0  33   6 432]]
#
# Precision (macro): 0.83420370687907
# Recall (macro): 0.7676286870303376
# F1-score (macro): 0.7581605755697899
#
# Classification Report:
#                     precision    recall  f1-score   support
#
#             LAYING       0.49      0.96      0.65       537
#            SITTING       0.84      0.26      0.40       491
#           STANDING       0.85      0.56      0.67       532
#            WALKING       0.93      0.98      0.95       496
# WALKING_DOWNSTAIRS       0.97      0.92      0.94       420
#   WALKING_UPSTAIRS       0.93      0.92      0.92       471
#
#           accuracy                           0.76      2947
#          macro avg       0.83      0.77      0.76      2947
#       weighted avg       0.83      0.76      0.75      2947
#
# (7352, 38)
